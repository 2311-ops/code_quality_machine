# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("output/labeled_dataset.csv")
df.head()
# Out:
#                                      repo  \
# 0                 public-apis/public-apis
# 1                 public-apis/public-apis
# 2                 public-apis/public-apis
# 3                 public-apis/public-apis
# 4  EbookFoundation/free-programming-books
#
#                                             repo_url   stars  \
# 0         https://github.com/public-apis/public-apis  424462
# 1         https://github.com/public-apis/public-apis  424462
# 2         https://github.com/public-apis/public-apis  424462
# 3         https://github.com/public-apis/public-apis  424462
# 4  https://github.com/EbookFoundation/free-progra...  385637
#
#                                file_path  file_size  mi_score  avg_cc  max_cc  \
# 0  scripts/tests/test_validate_format.py      18154     35.41    1.72       4
# 1   scripts/tests/test_validate_links.py       5725    100.00    1.36       2
# 2             scripts/validate/format.py       8464     39.64    4.18      14
# ...

# %%
df.tail()
# Out:
#                     repo                               repo_url  stars  \
# 1001  google/python-fire  https://github.com/google/python-fire  28171
# 1002  google/python-fire  https://github.com/google/python-fire  28171
# 1003  google/python-fire  https://github.com/google/python-fire  28171
# 1004  google/python-fire  https://github.com/google/python-fire  28171
# 1005  google/python-fire  https://github.com/google/python-fire  28171
#
#                         file_path  file_size  mi_score  avg_cc  max_cc  loc  \
# 1001               fire/parser.py       4697     67.28    3.00       8  132
# 1002     fire/parser_fuzz_test.py       3041     70.92   10.50      11   94
# 1003          fire/parser_test.py       6379     67.54    1.05       2  140
# 1004      fire/test_components.py      11723     45.89    1.38       3  568
# 1005  fire/test_components_bin.py        807     69.54    1.00       1   28
#
#       lloc  sloc  comments  blank  comment_ratio quality_label  \
# ...

# %%
df.isnull().sum()
# Out:
# repo             0
# repo_url         0
# stars            0
# file_path        0
# file_size        0
# mi_score         0
# avg_cc           0
# max_cc           0
# loc              0
# lloc             0
# sloc             0
# comments         0
# blank            0
# comment_ratio    0
# quality_label    0
# code             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006 entries, 0 to 1005
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   repo           1006 non-null   object
#  1   repo_url       1006 non-null   object
#  2   stars          1006 non-null   int64
#  3   file_path      1006 non-null   object
#  4   file_size      1006 non-null   int64
#  5   mi_score       1006 non-null   float64
#  6   avg_cc         1006 non-null   float64
#  7   max_cc         1006 non-null   int64
#  8   loc            1006 non-null   int64
#  9   lloc           1006 non-null   int64
#  10  sloc           1006 non-null   int64
#  11  comments       1006 non-null   int64
#  12  blank          1006 non-null   int64
#  13  comment_ratio  1006 non-null   float64
#  14  quality_label  1006 non-null   object
#  15  code           1006 non-null   object
# dtypes: float64(3), int64(8), object(5)
# memory usage: 125.9+ KB
